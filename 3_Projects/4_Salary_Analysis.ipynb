# %% [markdown]
# # How well do jobs and skills pay for Data Analysts?
#
# Methodology
# 1. Evaluate median salary for top 6 data jobs
# 2. Find median salary per skill for Data Analysts
# 3. Visualize for highest paying skills and most demanded skills

# %%
import pandas as pd
import ast
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %%
#Filter the dataset by the Country
df_us = df[df['job_country'] == 'United States'].dropna(subset=['salary_year_avg'])
df_us
# Out:
#        job_title_short  ...                                    job_type_skills
# 92       Data Engineer  ...                 {'programming': ['sql', 'python']}
# 100     Data Scientist  ...  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 116     Data Scientist  ...  {'analyst_tools': ['tableau'], 'libraries': ['...
# 146      Data Engineer  ...  {'libraries': ['hadoop', 'spark'], 'programmin...
# ...                ...  ...                                                ...
# 785563  Data Scientist  ...  {'analyst_tools': ['word', 'power bi', 'tablea...
# 785624   Data Engineer  ...  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641   Data Engineer  ...                                               None
# 785648  Data Scientist  ...  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785692  Data Scientist  ...         {'programming': ['python', 'matlab', 'r']}
#
# ...

# %%
# Getting a list of the top 6 posted jobs
job_titles = df_us['job_title_short'].value_counts().index[:6].to_list()
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
# Filtering the US dataset by the job titles
df_us_top6 = df_us[df_us['job_title_short'].isin(job_titles)]
df_us_top6
# Out:
#        job_title_short  ...                                    job_type_skills
# 92       Data Engineer  ...                 {'programming': ['sql', 'python']}
# 100     Data Scientist  ...  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 116     Data Scientist  ...  {'analyst_tools': ['tableau'], 'libraries': ['...
# 146      Data Engineer  ...  {'libraries': ['hadoop', 'spark'], 'programmin...
# ...                ...  ...                                                ...
# 785563  Data Scientist  ...  {'analyst_tools': ['word', 'power bi', 'tablea...
# 785624   Data Engineer  ...  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641   Data Engineer  ...                                               None
# 785648  Data Scientist  ...  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785692  Data Scientist  ...         {'programming': ['python', 'matlab', 'r']}
#
# ...

# %%
# Sorting the jobs based on the median of their average yearly salary
job_order = df_us_top6.groupby(by='job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index
job_order
# Out:
# Index(['Senior Data Scientist', 'Senior Data Engineer', 'Data Scientist',
#        'Data Engineer', 'Senior Data Analyst', 'Data Analyst'],
#       dtype='object', name='job_title_short')

# %%
#Plotting Top 6 Data Roles in the US along with their average yearly salary

sns.boxplot(data=df_us_top6, x= 'salary_year_avg', y='job_title_short', order=job_order)
sns.set_theme(style='ticks')

plt.title(label='Salary Distributions in the United States')
plt.xlabel('Yearly Salary (USD)')
plt.ylabel('')
plt.xlim(0,600000)
ticks_x = plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K')
plt.gca().xaxis.set_major_formatter(ticks_x)
plt.show()

# %% [markdown]
# # Investigate Median Salary vs Skill for Data Analysts

# %%
#Creating new dataframe and filtering by the position of Data Analyst and the country, United States
df_da_us1 = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()
df_da_us1 = df_da_us1.dropna(subset=['salary_year_avg'])
df_da_us1
# Out:
#        job_title_short  ...                                    job_type_skills
# 109       Data Analyst  ...  {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# 180       Data Analyst  ...         {'analyst_tools': ['excel', 'powerpoint']}
# 410       Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'visio', '...
# 988       Data Analyst  ...  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 1413      Data Analyst  ...  {'analyst_tools': ['excel', 'power bi'], 'prog...
# ...                ...  ...                                                ...
# 782637    Data Analyst  ...  {'databases': ['sql server'], 'programming': [...
# 782798    Data Analyst  ...                            {'other': ['terminal']}
# 783588    Data Analyst  ...  {'analyst_tools': ['excel'], 'libraries': ['ha...
# 783866    Data Analyst  ...                                   {'os': ['unix']}
# 784882    Data Analyst  ...  {'analyst_tools': ['tableau', 'excel', 'altery...
#
# ...

# %%
#Breaking the job skills out of the list
df_da_us1 = df_da_us1.explode('job_skills')
df_da_us1[['salary_year_avg', 'job_skills']].head(5)
# Out:
#      salary_year_avg job_skills
# 109          89000.0     python
# 109          89000.0          r
# 109          89000.0    alteryx
# 109          89000.0    tableau
# 180          90250.0      excel

# %%
#Finding the count and median average yearly salary for the each skill and sorting it in descending order by the median average yearly salary
df_da_top_pay = df_da_us1.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='median', ascending=False)
df_da_top_pay = df_da_top_pay.head(10)
df_da_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
#Finding the count and median average yearly salary for the each skill and sorting it in descending order by the count of the job skill
df_da_skills = df_da_us1.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

#Sorting this dataframe by the median of the salary yearly average
df_da_skills = df_da_skills.head(10).sort_values(by='median', ascending=False)

df_da_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
fig, ax = plt.subplots(2, 1)

sns.set_theme(style='ticks')

#Plot for Top 10 Highest Paid Skills
sns.barplot(data=df_da_top_pay, x='median', y=df_da_top_pay.index, ax=ax[0], hue='median', palette='dark:b_r', legend=False)
ax[0].set_title('Top 10 Highest Paid Skills for Data Analysts')
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

#Plot for Top 10 Most in Demand Skills
sns.barplot(data=df_da_skills, x='median', y=df_da_skills.index, ax=ax[1], hue='median', palette='light:b', legend=False)
ax[1].set_title('Top 10 Most in Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].set_xlim(ax[0].get_xlim())
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

plt.tight_layout()
plt.show()
