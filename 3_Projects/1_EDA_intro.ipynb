# %% [markdown]
# # Exploratory Data Analysis
#
# Roles to Explore

# %% [markdown]
# ## What are the most demanded skills for the top 3 most popular data roles (2)
#
# ### Methodology
# 1. Clean up skill column
# 2. Calculate skill count based on job_title_short
# 3. Plot initial findings
# 4. Calculate skill percentage
# 5. Plot final findings

# %% [markdown]
# ## How well do jobs and skills pay for Data Analysts? (3)
#
# ### Methodology
# 1. Evaluate median salary for all data jobs
# 2. Find median salary per skill for Data Analysts
# 3. Visualize for highest paying skills
# 4. Visualize for highest demanded skills

# %% [markdown]
# ## How well do jobs and skills pay for Data Analysts? (3)
#
# ### Methodology
# 1. Evaluate median salary for all data jobs
# 2. Find median salary per skill for Data Analysts
# 3. Visualize for highest paying skills
# 4. Visualize for highest demanded skills

# %% [markdown]
# ## What is the most optimal skill to learn for Data Analysts? (5)
#
# ### Methodology
# 1. Continue from last notebook to find percent of postings with skill
# 2. Visualize median salary vs percent skill demand
# 3. (Optional) Determine if certain technologies are more prevalent

# %%
import ast
import pandas as pd
import seaborn as sns
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x : ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# ## Filter for US Data Analyst Roles

# %%
df_da_us = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')]
df_da_us
# Out:
#        job_title_short  ...                                    job_type_skills
# 36        Data Analyst  ...                                               None
# 68        Data Analyst  ...           {'programming': ['r'], 'sync': ['zoom']}
# 73        Data Analyst  ...  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 79        Data Analyst  ...  {'analyst_tools': ['sas', 'word', 'excel'], 'p...
# 93        Data Analyst  ...  {'analyst_tools': ['power bi', 'excel', 'word'...
# ...                ...  ...                                                ...
# 785603    Data Analyst  ...  {'analyst_tools': ['excel'], 'other': ['flow']...
# 785626    Data Analyst  ...                      {'sync': ['microsoft teams']}
# 785685    Data Analyst  ...  {'analyst_tools': ['excel'], 'programming': ['...
# 785703    Data Analyst  ...                                               None
# 785705    Data Analyst  ...  {'analyst_tools': ['tableau'], 'programming': ...
#
# ...

# %%
df_plot = df_da_us['job_location'].value_counts().head(10).to_frame()

# %%
sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_location', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts of Jobs Locations for Data Analysts in the US')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %%
dict_column = {
    'job_work_from_home' : 'Work From Home',
    'job_no_degree_mention': 'Degree Requirement',
    'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1,3)
fig.set_size_inches((12,5))

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df_da_us[column].value_counts(), labels=['False', 'True'], autopct= '%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.show()

# %%
df_plot2 = df['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')

sns.barplot(data=df_plot2, x='count', y='company_name', hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title("Count of Data Analyst Jobs at Companies in the United States")
plt.xlabel("Number of Jobs")
plt.ylabel('')
plt.show()
