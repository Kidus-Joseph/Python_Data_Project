# %%
import pandas as pd

# %%
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
#Load Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
#Clean Data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short  ...                                    job_type_skills
# 0  Senior Data Engineer  ...                                               None
# 1          Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2         Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3         Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4         Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
#
# [5 rows x 17 columns]

# %%
df.tail()
# Out:
#           job_title_short  ...                                    job_type_skills
# 785736  Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737       Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738   Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739      Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740  Software Engineer  ...              {'cloud': ['aws'], 'other': ['flow']}
#
# [5 rows x 17 columns]

# %% [markdown]
# # Sample
# sample() is function that will take a random sample of items
# You can state how many results you would like returned

# %%
df.sample(10)
# Out:
#               job_title_short  ...                                    job_type_skills
# 324433         Data Scientist  ...  {'libraries': ['pandas', 'tensorflow', 'scikit...
# 386523          Data Engineer  ...  {'cloud': ['aws', 'redshift'], 'libraries': ['...
# 582173    Senior Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'da...
# 33616    Senior Data Engineer  ...  {'analyst_tools': ['sas', 'power bi'], 'progra...
# 56115          Data Scientist  ...                                               None
# 781420       Business Analyst  ...                                               None
# 202338   Senior Data Engineer  ...  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 18876       Software Engineer  ...  {'libraries': ['spark'], 'os': ['linux'], 'oth...
# 496498           Data Analyst  ...                       {'analyst_tools': ['excel']}
# 402557  Senior Data Scientist  ...  {'analyst_tools': ['sas', 'spss', 'tableau'], ...
#
# [10 rows x 17 columns]

# %%
#If there is a result that you do like, you can state the random state to get the results everytime
df.sample(10, random_state=4)
# Out:
#              job_title_short  ...                                    job_type_skills
# 23956   Senior Data Engineer  ...                              {'cloud': ['oracle']}
# 158106          Data Analyst  ...                                               None
# 86891   Senior Data Engineer  ...  {'cloud': ['databricks', 'snowflake'], 'progra...
# 402323      Business Analyst  ...                      {'analyst_tools': ['sheets']}
# 297166  Senior Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['spark', 'pan...
# 390024         Data Engineer  ...  {'cloud': ['azure'], 'programming': ['python',...
# 549326        Data Scientist  ...                        {'programming': ['python']}
# 481114        Cloud Engineer  ...                    {'cloud': ['gcp', 'snowflake']}
# 718488        Data Scientist  ...                           {'programming': ['sql']}
# 422600        Data Scientist  ...                 {'programming': ['sql', 'python']}
#
# [10 rows x 17 columns]

# %% [markdown]
# # Copy
# copy() will make a copy of the object's indices and data

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_original
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %%
df_altered = df_original

df_altered
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %%
df_altered.loc[:5, "salary_year_avg"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()

# %%
median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(value=median_salary)

# %%
df_altered.loc[:5, "salary_year_avg"]
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# # Why did df_altered and df_original have the same result?
#
# Because we used the "=" operator, we copied the id of the df_original variable to the df_altered variable
# Therefore, the variables are referencing the same dataframe

# %%
id(df_original)
# Out:
# 2781117948176

# %%
id(df_altered)
# Out:
# 2781117948176

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print("ID of OG dataset : ", id(df_original))
print("ID of Altered dataset: ", id(df_altered))
print("Are they the same dataframes? : ", id(df_original) == id(df_altered))
# Out:
# ID of OG dataset :  2781346605904
# ID of Altered dataset:  2782746224592
# Are they the same dataframes? :  False

# %%
median_salary = df_altered['salary_year_avg'].median()

df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(value=median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, "salary_year_avg"]
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
