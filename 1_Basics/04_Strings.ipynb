# %% [markdown]
# # Strings

# %%
"This is a string in double quotes"
# Out:
# 'This is a string in double quotes'

# %%
'This is a string in single quotes'
# Out:
# 'This is a string in single quotes'

# %%
This is string without quotes
# Out:
#   File "<ipython-input-3-9d1eccd166ea>", line 1
#     This is string without quotes
#                    ^
# SyntaxError: invalid syntax

# %%
skill = 'Python'

# %%
type(skill)
# Out:
# str

# %% [markdown]
# # Manipulating Strings

# %%
skill.upper()
# Out:
# 'PYTHON'

# %%
skill.lower()
# Out:
# 'python'

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
"Python".lower()
# Out:
# 'python'

# %%
str.lower("Python")
# Out:
# 'python'

# %%
skill = "Python"

# %%
skill.lower()
# Out:
# 'python'

# %%
skill
# Out:
# 'Python'

# %%
skill.replace("P", "J")
# Out:
# 'Jython'

# %% [markdown]
# Understanding keyword arguments

# %%
job_title = "Data Analyst" #rename Data with Dota

# %%
job_title = job_title.replace('a', 'o', 2)

# %%
job_title.split(" ", maxsplit=1)
# Out:
# ['Doto', 'Analyst']

# %%
str.__add__("Data ", "Analyst")
# Out:
# 'Data Analyst'

# %%
"Data".__add__(" Analyst")
# Out:
# 'Data Analyst'

# %%
"Data" + " Analyst"
# Out:
# 'Data Analyst'

# %%
"Data Analyst "*10
# Out:
# 'Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst Data Analyst '

# %%
"Data Analyst".__len__()
# Out:
# 12

# %%
len("Data Analyst")
# Out:
# 12
