# %% [markdown]
# # Create a Variable

# %% [markdown]
# variable_name = name

# %%
salary = 100000

# %%
salary
# Out:
# 100000

# %% [markdown]
# # Calculate the Following
#
# Total Salary = (Base Salary) * (1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = 0.10

# %%
total_salary = base_salary * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %% [markdown]
# # Variables aren't only numbers
#
# They can be used for other data types
# - integers (JobID)
# - string (String)
# - integers stored as strings (String, but stored for numerical type for calculations)
# - boolean (Job Work from Home)

# %%
company_name = 'DataWiz Inc.'

# %%
company_name
# Out:
# 'DataWiz Inc.'

# %%
job_wfh = True

# %%
job_wfh
# Out:
# True

# %%
job_id = 101
job_title = 'Data Analyst'
job_salary = 125000

# %%
print("Data Job Description")
print("++++++++++++++++++++++++++++++")
print("Job ID: ", job_id)
print("Company Name:", company_name)
print("Job Title: ", job_title)
print("Salary: ", job_salary)
print("WFH: ", job_wfh)
# Out:
# Data Job Description
# ++++++++++++++++++++++++++++++
# Job ID:  101
# Company Name: DataWiz Inc.
# Job Title:  Data Analyst
# Salary:  125000
# WFH:  True
