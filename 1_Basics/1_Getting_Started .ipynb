# %%
"This is a coding cell"
# Out:
# 'This is a coding cell'

# %% [markdown]
# **How to Run a Cell**

# %%
"You can do either of following: Click the run button, Select the cell and type CMD/Crtl + Enter, or Shift enter (this last step will execute cell and select the next cell)"
# Out:
# 'You can do either of following: Click the run button, Select the cell and type CMD/Crtl + Enter, or Shift enter (this last step will execute cell and select the next cell)'

# %% [markdown]
# Python Basics

# %%
2+2
3*3
# Out:
# 9

# %%
print(2+2)
print(3*3)
# Out:
# 4
# 9

# %% [markdown]
# # Make a Comment

# %% [markdown]
# What if you wanted to include something in your code like a note?
#
#
# *   Include a # before the line
# *   This is called a comment
#
#
# The python interpreter will ignore the comment or everything to the right of the hashtag

# %%
#This is a comment

# %% [markdown]
# # Markdown Basics
#
# Inside your text cells you are allowed to use a markdown language called Markdown that allows you to format the text cells

# %% [markdown]
# This is a normal text
#  # This is a Heading
#
# **This sentence is in bold**
#
# 1. one of list
# 2. two of list
# 3. three of list
#
# [This is sentence is text that goes on the side of a link. The link goes inside a pair of parentheses (www.google.com)]
